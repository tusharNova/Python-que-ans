# %% [markdown]
# ## New project started

# %%
print("hey user")
# Out:
# hey user

# %%
for i in range(1, 6):
    for j in range(i):
        print("*" , end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(1, 6):
    for j in range(1 ,i+1):
        print(j*i , end=" ")
    print()
# Out:
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25

# %%
for i in range(1, 6):
    for j in range(1 ,i+1):
        print(j*i , end=" ")
    print()
# Out:
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25

# %%
print("sadfasdf")
# Out:
# sadfasdf
